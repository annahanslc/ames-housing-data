# %% [markdown]
# # EDA 1 - Nulls

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', 81)
pd.set_option('display.max_rows', 81)

# %%
df = pd.read_csv('../data/train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
string_columns = df.select_dtypes(include=['object', 'string'])
string_columns.shape
# Out:
# (1460, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df.isna().sum() / df.shape[0]
# Out:
# Id               0.000000
# MSSubClass       0.000000
# MSZoning         0.000000
# LotFrontage      0.177397
# LotArea          0.000000
# Street           0.000000
# Alley            0.937671
# LotShape         0.000000
# LandContour      0.000000
# Utilities        0.000000
# LotConfig        0.000000
# LandSlope        0.000000
# Neighborhood     0.000000
# Condition1       0.000000
# Condition2       0.000000
# BldgType         0.000000
# HouseStyle       0.000000
# OverallQual      0.000000
# OverallCond      0.000000
# YearBuilt        0.000000
# YearRemodAdd     0.000000
# RoofStyle        0.000000
# RoofMatl         0.000000
# Exterior1st      0.000000
# Exterior2nd      0.000000
# MasVnrType       0.597260
# MasVnrArea       0.005479
# ExterQual        0.000000
# ExterCond        0.000000
# Foundation       0.000000
# BsmtQual         0.025342
# BsmtCond         0.025342
# BsmtExposure     0.026027
# BsmtFinType1     0.025342
# BsmtFinSF1       0.000000
# ...

# %% [markdown]
# # All Features with Nulls

# %%
columns_with_na = pd.DataFrame(df.isna().sum())
only_cols_with_na = columns_with_na[columns_with_na[0] > 0]
only_cols_with_na
# Out:
#                  0
# LotFrontage    259
# Alley         1369
# MasVnrType     872
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC        1453
# Fence         1179
# MiscFeature   1406

# %% [markdown]
# # EDA: Lot Frontage

# %%
df[df['LotFrontage'] == 0]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
lot_frontage_values = df['LotFrontage'].value_counts().sort_index()
lot_frontage_values
# Out:
# LotFrontage
# 21.0     23
# 24.0     19
# 30.0      6
# 32.0      5
# 33.0      1
#          ..
# 160.0     1
# 168.0     1
# 174.0     2
# 182.0     1
# 313.0     2
# Name: count, Length: 110, dtype: int64

# %%
plt.hist(lot_frontage_values)
# Out:
# (array([91., 12.,  1.,  3.,  2.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  15.2,  29.4,  43.6,  57.8,  72. ,  86.2, 100.4, 114.6,
#         128.8, 143. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Decision: LotFrontage nulls impute as 0. It seems like null means no lot frontage, because the min LotFrontage in dataset is 21.0

# %% [markdown]
# # EDA: Alley

# %%
df['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %% [markdown]
# ### Decision: Impute nulls as NA for no alley access

# %% [markdown]
# # EDA: MasVnrType

# %%
df['MasVnrType'].value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %% [markdown]
# ##### Feature should have None and Stone too.
#
# ### Decision: Impute nulls as None.

# %% [markdown]
# # EDA: MasVnrArea

# %%
plt.hist(df['MasVnrArea'])
# Out:
# (array([1.077e+03, 2.190e+02, 9.400e+01, 2.900e+01, 1.900e+01, 6.000e+00,
#         4.000e+00, 2.000e+00, 1.000e+00, 1.000e+00]),
#  array([   0.,  160.,  320.,  480.,  640.,  800.,  960., 1120., 1280.,
#         1440., 1600.]),
#  <BarContainer object of 10 artists>)

# %%
df['MasVnrArea'].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %% [markdown]
# ### Decision: impute null with median (0)

# %% [markdown]
# # EDA BsmtQual

# %%
df['BsmtQual'].value_counts()
# Out:
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64

# %%
bsmtqual_null = df[df['BsmtQual'].isna()]
bsmtqual_null.head()
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 17    18          90       RL         72.0    10791   Pave   NaN      Reg
# 39    40          90       RL         65.0     6040   Pave   NaN      Reg
# 90    91          20       RL         60.0     7200   Pave   NaN      Reg
# 102  103          90       RL         64.0     7018   Pave   NaN      Reg
# 156  157          20       RL         60.0     7200   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 17          Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 39          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 90          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 102         Bnk    AllPub    Inside       Gtl      SawyerW       Norm
# 156         Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ##### BsmtQual null has NaN in all features related to basement. This likely means that the home didn't have a basement.
#
# ### Decision Impute null as "NA" which means no basement

# %% [markdown]
# # EDA BsmtCond

# %%
df['BsmtCond'].value_counts()
# Out:
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64

# %% [markdown]
# ##### NA stands for No Basement
#
# ### Decision: impute nulls as "NA"

# %% [markdown]
# # EDA BsmtExposure, BsmtFinType1, BsmtFinType2

# %%
bsmtqual_null[['BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']]
# Out:
#      BsmtExposure BsmtFinType1 BsmtFinType2
# 17            NaN          NaN          NaN
# 39            NaN          NaN          NaN
# 90            NaN          NaN          NaN
# 102           NaN          NaN          NaN
# 156           NaN          NaN          NaN
# 182           NaN          NaN          NaN
# 259           NaN          NaN          NaN
# 342           NaN          NaN          NaN
# 362           NaN          NaN          NaN
# 371           NaN          NaN          NaN
# 392           NaN          NaN          NaN
# 520           NaN          NaN          NaN
# 532           NaN          NaN          NaN
# 533           NaN          NaN          NaN
# 553           NaN          NaN          NaN
# 646           NaN          NaN          NaN
# 705           NaN          NaN          NaN
# 736           NaN          NaN          NaN
# 749           NaN          NaN          NaN
# 778           NaN          NaN          NaN
# ...

# %% [markdown]
# ##### As suspected, the nulls related to basements are regarding the same homes.
#
# ### Decision: Impute nulls in BsmtExposure, BsmtFinType1, BsmtFinType2 all as "NA" for no basement

# %% [markdown]
# # EDA: Electrical

# %%
df['Electrical'].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
df[df['Electrical'].isna()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1379  1380          80       RL         73.0     9735   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1379         Lvl    AllPub    Inside       Gtl       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1379       Norm     1Fam       SLvl            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1379          2007     Gable  CompShg     VinylSd     VinylSd        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1379         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1379           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %% [markdown]
# ##### Missing for at random
#
# ### Decision: Impute with median (SBrkr)

# %% [markdown]
# # EDA: FireplaceQu

# %%
df['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
df['FireplaceQu'].isna().sum()
# Out:
# np.int64(690)

# %% [markdown]
# ##### NA is an option, but no observations of NA. nulls must be NA

# %% [markdown]
# ### Decision: Impute null as "NA" for no fireplace

# %% [markdown]
# # EDA GarageType & other garage-related features

# %%
df['GarageType'].value_counts()
# Out:
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64

# %%
df[df['GarageType'].isna()];

# %% [markdown]
# ##### All the missing values in GarageType are also missing in the other Garage related features. There must be no garage.
#
# ### Decision: Impute all missing values in GarageType, GarageFinish, GarageQual, and GarageCond as "NA" for no garage

# %% [markdown]
# # EDA PoolQC

# %%
df['PoolQC'].value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %% [markdown]
# ### Decision: Impute nulls as NA for no pool

# %% [markdown]
# # EDA Fence

# %%
df['Fence'].value_counts()
# Out:
# Fence
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: count, dtype: int64

# %% [markdown]
# ### Decision: Impute nulls as NA for no fence

# %% [markdown]
# # EDA MiscFeature

# %%
df['MiscFeature'].value_counts()
# Out:
# MiscFeature
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: count, dtype: int64

# %% [markdown]
# ### Decision: impute nulls with NA for None
